# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranajit04/Machine-Learning-Flyrank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pranajit04/Machine-Learning-Flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## I'm choosing Lane 2: Refresh / Content Opportunity Scoring. This lane ranks which content pages should be reviewed first for refresh,
##based on evidence like declining traffic, staleness, or missed CTR opportunity.
##I'm choosing this because Notebooks 01 and 02 already showed me the core workflow — comparing a hand-written rule against a trained model to prioritize pages —
##and I want to build on that same foundation rather than start a new type of problem from scratch.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
##Research question: Given a page's search and engagement history, which pages should be reviewed first for a content refresh? Unit of analysis: one content page (one row = one page).
##Decision: which pages a content/SEO reviewer should look at first, out of many.
##Action: a reviewer updates, expands, or otherwise refreshes the flagged page. Cost of a wrong
##recommendation: wasted reviewer time on a page that didn't actually need attention, OR a genuinely declining page gets missed because it wasn't flagged — both waste limited review capacity.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Pranajit04/Machine-Learning-Flyrank/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)
print('Shape (rows, columns):', df.shape)
print(df['trend_direction'].value_counts())
# Out:
# Shape (rows, columns): (30000, 44)
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# *The starter dataset has about 30,000 rows. A simple hand-written rule only reaches Precision@50 = 0.240 (about 12 of the top 50 picks are right). A random forest model reaches Precision@50 = 0.740 (about 37 of 50 right). This ~3x gap between the hand rule and a trained model, on real data, suggests a learned ranking genuinely captures signal a fixed rule misses — which is why this looks worth pursuing over the next 7 weeks.*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This is decision-support, not proof. A high refresh score means a page is a good candidate to review first — not a guarantee that refreshing it will cause traffic to recover. Proving causation would require an actual experiment (e.g. refresh some pages, leave others alone, compare outcomes), which this data alone can't give me. I will describe findings as observed or associated, not proven or caused. I will not claim to have discovered a Google ranking factor.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
